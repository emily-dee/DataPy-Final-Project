# %%
df['Annual Mean'] = df['Annual Mean'].fillna(df['Hourly Mean'] * 2080)

# %%
df.loc[df['Job Title'].str.contains('Musician')].head()
# Out:
#            State State Abbreviation              Job Title Occupation Title  \
# 255      Alabama                 AL  Musicians and Singers         detailed
# 1593     Arizona                 AZ  Musicians and Singers         detailed
# 2319    Arkansas                 AR  Musicians and Singers         detailed
# 3064  California                 CA  Musicians and Singers         detailed
# 3882    Colorado                 CO  Musicians and Singers         detailed
#
#       Total Employed  Employment per 1,000 Jobs  Hourly Mean  Annual Mean  \
# 255            230.0                      0.110        13.71      28516.8
# 1593           390.0                      0.123        55.25     114920.0
# 2319            80.0                      0.060        60.08     124966.4
# 3064          5540.0                      0.309        51.73     107598.4
# 3882           300.0                      0.107        27.28      56742.4
#
# ...

# %%
df['Hourly Mean'] = df['Hourly Mean'].fillna(df['Annual Mean'] / 2080)

# %%
df.loc[df['Job Title'].str.contains('Coaches')].head()
# Out:
#            State State Abbreviation           Job Title Occupation Title  \
# 253      Alabama                 AL  Coaches and Scouts         detailed
# 952       Alaska                 AK  Coaches and Scouts         detailed
# 1590     Arizona                 AZ  Coaches and Scouts         detailed
# 2318    Arkansas                 AR  Coaches and Scouts         detailed
# 3059  California                 CA  Coaches and Scouts         detailed
#
#       Total Employed  Employment per 1,000 Jobs  Hourly Mean  Annual Mean  \
# 253           2880.0                      1.404          NaN      54840.0
# 952            470.0                      1.506          NaN      46510.0
# 1590          3470.0                      1.108          NaN      62240.0
# 2318          1720.0                      1.355          NaN      48020.0
# 3059         28700.0                      1.599          NaN      65560.0
#
#       Hourly 10th Percentile  Hourly 25th Percentile  Hourly Median  \
# ...
